# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaazCode/Machine-Learning/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 3 main parts
# 1. Supervised
# 2. unsupervised
# 3. Reinfor

# %%
# on the baiss of dataset we can predict

# data set contains rows and column

# in supervised learning we're having labelled data it means input attached to the output


# in unsupervised learning we're having un-labelled data okay. - we're not having the output attacehd to input

# %%
# supervised is classified into 2 types
# 1. Regression : When we want to predict anything as a numeric at that time we're making use of regression - any numeric values
# 2. Classification : if we want to predict any classes at that time we make use of classificaiton algorithm

# %%
# Types of regression
#1. Linear Regression
#2. Multi-linear regression
#3. Polynominal regression
#4. Ridge Regression
#5. Lasso Regression

# %%
Simple Linear Regression
2️⃣ Multiple Linear Regression
3️⃣ Polynomial Regression
4️⃣ Ridge & Lasso
5️⃣ Decision Tree Regressor
6️⃣ Random Forest Regressor
7️⃣ Gradient Boosting
8️⃣ KNN Regressor
9️⃣ SVR

# %%
# Linear Regression

# It is a method used to find the relationship between two things.

# One thing is totally depend on another thing.

# Example:
Experience     Salary
1 ->            3LPA
2 ->            4LPA
3 ->            5+LPA

Expereince = Independent variable (X)
Salary     = Depenedent variable (Y)

Expereience is dependent column on salary.


# Example 2
92 marks -> A+ Grade

# %% [markdown]
# ![Screenshot 2025-12-15 at 6.02.44 PM.png](data:image/png;base64,...)

# %%
# above this digram is of simple or single linear regression .
# Working of linear regression is it seperate the two thing with the help straight line

# %%
# Formula:
Y = mX + c
Y -> Target output
X -> Input values
m -> How fast Y changes.
c -> starting value

# %%
# Why we use
# 1. If the prediction is simple
# 2. single Linear  regression predict the output based on single attribute

# disadvantage of this:
# 1. linear regression wont be okay for crucial prediction why because it takes only one attributes

# %%
# so for overcome this single linear regression we're having multi-linear regression.

# Multi-linear regressions.

# 1. It takes more than one input so this is mult-linear regressions.

# Linear regression -> 1 Input -> 1 output
# Multi-linear regression -> Many inputs -> 1 output

# %%
# Formula
# Y = b1x1 + b2X2 + b3x3 + b4X4 ....+bnXn

# %%
# Y -> Output (what we want to predict)
# x1x2x3 -> input variables
# b1b2b3. -> coeffiecent
