# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaazCode/Machine-Learning/blob/main/Scikit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Scikit learn is a machine learning library that is used to ccreate a machine learning model easily and quickly

# Instead of writing everything from the scratch scikit learn gives us :
# Pre-built algorithm
# Function to train the model
# Tools to clean and prepare the data


# So its like
# Photoshop for working with photo
# Excel for working with data  , so same like this
# Scikit-learn for doing machine learning

# %%
# Flow for machine learning
# First cook food
# Then taste the food

# %%
# scikit learn it is kind of tool box without scikit learn we have to write 1000 line of code but with scikit learn only 5 lines of code

# %% [markdown]
# # Scikit learn flow
#
# Step 1. Understand and installation
#
# Step 2. Understand the data structure  - try to understand this X feature and y features
#
# X -> Feature input
# Y -> Label output
#
# X is the input feature which we provide whreas Y is the output which we have to predict based on the basis of input given
#
# so for example
# If we want to predict the student will pass or fail , then the x feature can be
# 1. Hour studied
# 2. Number of assignment completed
# 3. Attendance
#
#
# X = [[5, 10, 90],
#      [2, 4, 60],
#      [7, 12, 95]]
#
# Each row one student each row one column
#
# Y is the correct output for each row
#
# Y = [1,0,1]
#
# 1 -> Pass
# 0 -> Fail
#
#
# Step 3: Train test split
#
# Before training the model we must split the data into training part and testing part.
# Training part data is used to train the model whreas testing part data is used to test the model based on the trained data.
#
# Always we're putting the ration of 80 - 20 80 for trainning and 20 for testing.
#
# Step 4 : Model of classification and Regression.
#
# Step 5: Data Pre-processing - Label Encodin, one hot encoding, scaling, handling missing values, etc.
#
#
# Step 6: Model Evaluation
# Model evaluation means we're checking how good is our machine learning model is.
#
# Example - You write an exam , teacher checks the exam
# Same you build an model then you check how it works.
#
# Without evaluation we dont know weather the model is right or wrong
#
#
# we're having classification and regression so in classification we have to classify the class so its having
#
# classification -
#
# 1. Accuracy
# 2. Precision
# 3. Recall
# 4. F1 Score
# 5. Confusion matrix
#
#
# Regression
# 1. MAE - Mean absolute error
# 2. MSE - Mean squared error
# 3. RMSE - Root mean squared error
# 4. R2 score -
#
#
# Example
# If we built a model to detect the mail is spam or not
#
# out of 100 email.
#
# 90 has been classified properly
# 10 has not been classified properly
#
# Accuracy - 90%
#
# Example for regression
#
# So lets suppose we're  predict the price of house so we're getting 50 okay so we cannot say the model accuracy is 50 this does not make any sense
#
# Step 7: Hyper paramter tuining
#
# Hyper paramter tuning means lets suppose the accuracy of your model is low and if you want to boost that so for that we're making use of hyper parameter
#
# exmaple you're cooking food and lets suppose you had tested but you feel there's low salt it required some salt so we're adding some salt into it and then again we're checking so thats called hyper paramter tuining we're make it more perfect

# %%
# Step 01: Install the library

! pip install scikit-learn

# Here we're using online editor so we dont need to install this library because this editor having already install library we just have to import it

# %%
# step 02: Import a model

# %% [markdown]
# sklearn has three main types of model
# 1. Classification model
#
# 2. Regression model
#
# 3. Clustering
#
#
# Other models are
#
# 1. Preprocessing
#
# 2. train test split
#
# 3. Model evaluation
#
# 4. Hyperparameter tuining

# %% [markdown]
# # Regression Models
#
# Regression model is called as regressor

# %%
# Regression Model -> If we want to work with number at that time we make use of regression

# Model
# 1. LinearRegressor
# 2. DecisionTreeRegressor
# 3. RandonForestRegressor
# 4. SupportvectorRegressor

#Example of importing

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %% [markdown]
# # Classification Models
#
# classification model is called as classifier

# %%
# Classification Model -> if we want to work with the classes at that time we're making use of classifer

# Example of importing classification models

# Model

# 1.Logistic Regression
# 2.Decision Tree classifier
# 3. Random Forest

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %% [markdown]
# # Unsupervised - Clustering
#
# Group Data into cluster's
#
# 1. KMeans
#
# 2. DBSCN

# %%
# model
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %% [markdown]
# # Other model

# %%
# Preprocessing data library

# Scale data -> StandardScaler and min max scalar
# Encode categorical values -> LabelEncode and One-hot-encoding

# This are the pre-processing library

from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder

# so here this all are the pre-processing librray

# %%
# Train and test

from sklearn.model_selection import train_test_split

# %%
# Model Evaluation

# Classification → accuracy_score, precision_score, confusion_matrix

# Regression → mean_squared_error, r2_score

from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error, r2_score

# %%
# Hyperparameter Tuning

# GridSearchCV, RandomizedSearchCV

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
