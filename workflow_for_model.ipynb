# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaazCode/Machine-Learning/blob/main/workflow_for_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Step 01: Import the libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This is Medical cost predication project using machine learning here im doing the entire workflow which are required while building machine learning model

# %% [markdown]
# **Step 02: Load the dataset**

# %%
medical_cost = pd.read_csv('medical_cost_prediction_dataset.csv')

# %% [markdown]
# **About Dataset**
#
# Demographic Features
#
# age	Age of the patient (18–90 years)
# gender	Gender of the patient (Male / Female)
#
#
# Lifestyle & Health Behavior
#
# smoker	Smoking status (Yes / No)
# physical_activity_level	Physical activity level (Low / Medium / High)
# daily_steps	Average steps per day
# sleep_hours	Average sleep duration (hours)
#
#
# Medical Conditions
#
# diabetes	Presence of diabetes (0 = No, 1 = Yes)
# hypertension	High blood pressure indicator
# heart_disease	History of heart disease
#
#
# Healthcare Utilization
#
# doctor_visits_per_year	Number of doctor visits per year
# hospital_admissions	Number of hospital admissions
#
#
# Insurance & Location
#
# insurance_type	Type of insurance (None / Government / Private)
# insurance_coverage_pct	Insurance coverage percentage

# %%
medical_cost.head()
# Out:
#    age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0   69    Male  29.4     No         1             0              0       0
# 1   32  Female  22.9     No         1             0              0       0
# 2   89    Male  25.7     No         0             0              0       0
# 3   78    Male  31.9    Yes         0             1              0       0
# 4   38    Male  27.7     No         0             0              0       0
#
#   physical_activity_level  daily_steps  sleep_hours  stress_level  \
# 0                  Medium        14825          4.4             8
# 1                  Medium         3620          6.0             7
# 2                    High        10578          4.5             7
# 3                     Low         6226          8.6             9
# 4                    High         6253          5.7             3
#
#    doctor_visits_per_year  hospital_admissions  medication_count  \
# ...

# %% [markdown]
# # **EDA**

# %% [markdown]
# **View Data**

# %% [markdown]
# head() -> function it is used to get the top 5 values from the dataset

# %%
medical_cost.head()
# Out:
#    age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0   69    Male  29.4     No         1             0              0       0
# 1   32  Female  22.9     No         1             0              0       0
# 2   89    Male  25.7     No         0             0              0       0
# 3   78    Male  31.9    Yes         0             1              0       0
# 4   38    Male  27.7     No         0             0              0       0
#
#   physical_activity_level  daily_steps  sleep_hours  stress_level  \
# 0                  Medium        14825          4.4             8
# 1                  Medium         3620          6.0             7
# 2                    High        10578          4.5             7
# 3                     Low         6226          8.6             9
# 4                    High         6253          5.7             3
#
#    doctor_visits_per_year  hospital_admissions  medication_count  \
# ...

# %%
# tail() -> function it is used to get last 5 values from the dataset
medical_cost.tail()
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 4995   77  Female  19.7    Yes         0             0              0       0
# 4996   43  Female  23.9    Yes         0             0              0       0
# 4997   58  Female  31.1     No         0             0              0       0
# 4998   53    Male  27.6     No         0             0              0       0
# 4999   40    Male  25.8     No         0             0              0       0
#
#      physical_activity_level  daily_steps  sleep_hours  stress_level  \
# 4995                     Low         7825          5.7             3
# 4996                  Medium         9054          8.4             7
# 4997                  Medium         6299          6.7             3
# 4998                  Medium         8379          6.2             8
# 4999                     Low         2000          5.3             5
#
#       doctor_visits_per_year  hospital_admissions  medication_count  \
# ...

# %%
#head(no_of_rows you want)
medical_cost.head(10)
# here im telling i want 10 data from top
# Out:
#    age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0   69    Male  29.4     No         1             0              0       0
# 1   32  Female  22.9     No         1             0              0       0
# 2   89    Male  25.7     No         0             0              0       0
# 3   78    Male  31.9    Yes         0             1              0       0
# 4   38    Male  27.7     No         0             0              0       0
# 5   41    Male  25.7     No         0             0              0       0
# 6   20  Female  23.0    Yes         0             0              0       0
# 7   39  Female  22.8     No         0             0              0       0
# 8   70    Male  21.7    Yes         0             0              0       0
# 9   19    Male  23.3     No         0             0              0       0
#
#   physical_activity_level  daily_steps  sleep_hours  stress_level  \
# 0                  Medium        14825          4.4             8
# ...

# %% [markdown]
# ## **Shape & size**

# %%
# shape : It is used to check the number of rows and columns in a datset

medical_cost.shape
# Out:
# (5000, 20)

# %%
# column names
medical_cost.columns
# Out:
# Index(['age', 'gender', 'bmi', 'smoker', 'diabetes', 'hypertension',
#        'heart_disease', 'asthma', 'physical_activity_level', 'daily_steps',
#        'sleep_hours', 'stress_level', 'doctor_visits_per_year',
#        'hospital_admissions', 'medication_count', 'insurance_type',
#        'insurance_coverage_pct', 'city_type', 'previous_year_cost',
#        'annual_medical_cost'],
#       dtype='object')

# %% [markdown]
# ## **Dataset info**

# %%
# Medical info -> Used to get the information of the entire dataset like how much null values are there
# and all the data types of column so we can understand the dataset proeprly
medical_cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      5000 non-null   int64
#  1   gender                   5000 non-null   object
#  2   bmi                      5000 non-null   float64
#  3   smoker                   5000 non-null   object
#  4   diabetes                 5000 non-null   int64
#  5   hypertension             5000 non-null   int64
#  6   heart_disease            5000 non-null   int64
#  7   asthma                   5000 non-null   int64
#  8   physical_activity_level  5000 non-null   object
#  9   daily_steps              5000 non-null   int64
#  10  sleep_hours              5000 non-null   float64
#  11  stress_level             5000 non-null   int64
#  12  doctor_visits_per_year   5000 non-null   int64
#  13  hospital_admissions      5000 non-null   int64
# ...

# %% [markdown]
# # **Dataset Summary**

# %%
# checking the summary of dataset
medical_cost.describe()
# Out:
#                age          bmi     diabetes  hypertension  heart_disease  \
# count  5000.000000  5000.000000  5000.000000   5000.000000     5000.00000
# mean     53.299000    25.970820     0.207600      0.288000        0.14220
# std      20.646851     5.046651     0.405629      0.452876        0.34929
# min      18.000000     6.400000     0.000000      0.000000        0.00000
# 25%      36.000000    22.600000     0.000000      0.000000        0.00000
# 50%      53.000000    25.900000     0.000000      0.000000        0.00000
# 75%      71.000000    29.400000     0.000000      1.000000        0.00000
# max      89.000000    43.600000     1.000000      1.000000        1.00000
#
#             asthma   daily_steps  sleep_hours  stress_level  \
# count  5000.000000   5000.000000  5000.000000   5000.000000
# mean      0.096400   7993.216800     6.488140      5.475400
# std       0.295169   4052.127069     1.443361      2.892312
# ...

# %%
# bydefault we're getting summary of numeric column but if we want a summary of object column then we have to mentioned
medical_cost.describe(include='object')
# Out:
#         gender smoker physical_activity_level insurance_type city_type
# count     5000   5000                    5000           3952      5000
# unique       2      2                       3              2         3
# top     Female     No                     Low        Private     Urban
# freq      2519   3779                    1996           1979      2474

# %% [markdown]
# ## **choosing column**

# %%
# If we want to choose any column then we can choose in this way
medical_cost['gender']
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3         Male
# 4         Male
#          ...
# 4995    Female
# 4996    Female
# 4997    Female
# 4998      Male
# 4999      Male
# Name: gender, Length: 5000, dtype: object

# %% [markdown]
# ## **Duplicated rows**

# %%
# If we want to check the duplicates rows then we have to do this
medical_cost.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
# duplicated sum
medical_cost.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **Unique values**

# %%
# If we want to check the unique value from the column then we have to use unique() function

# %%
medical_cost['gender'].unique()

# so here in gender column we're having 2 different types of unqiue values are present
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# # **Dataset Cleaning**

# %%
# 1. Missing values
# 2. Removing duplicated data
# 3.

# %% [markdown]
# ## 1. Missing values
#
# -> What to check?
#
# 1. Empty cells
#
# 2. NaN / Non Values
#
#
# What to do ?
# 1. Remove rows
#
# 2. Fill values by mean / median / mode
#
# 3. ffill & bfill

# %%
medical_cost.shape
# Out:
# (5000, 20)

# %% [markdown]
# what to check ?
#
# Firstly, we have to check the empty cells and after getting empty cells we have to fix it.

# %%
# So for checking the empty cells we will do
medical_cost.isnull()
# Out:
#         age  gender    bmi  smoker  diabetes  hypertension  heart_disease  \
# 0     False   False  False   False     False         False          False
# 1     False   False  False   False     False         False          False
# 2     False   False  False   False     False         False          False
# 3     False   False  False   False     False         False          False
# 4     False   False  False   False     False         False          False
# ...     ...     ...    ...     ...       ...           ...            ...
# 4995  False   False  False   False     False         False          False
# 4996  False   False  False   False     False         False          False
# 4997  False   False  False   False     False         False          False
# 4998  False   False  False   False     False         False          False
# 4999  False   False  False   False     False         False          False
#
#       asthma  physical_activity_level  daily_steps  sleep_hours  stress_level  \
# ...

# %%
# So for checking the sum of empty cell we have to do
medical_cost.isnull().sum()

# so here we're getting there are 1048 missing values then we have to fix that values using
# ffill / bfill or mean, mode, median
# Out:
# age                           0
# gender                        0
# bmi                           0
# smoker                        0
# diabetes                      0
# hypertension                  0
# heart_disease                 0
# asthma                        0
# physical_activity_level       0
# daily_steps                   0
# sleep_hours                   0
# stress_level                  0
# doctor_visits_per_year        0
# hospital_admissions           0
# medication_count              0
# insurance_type             1048
# insurance_coverage_pct        0
# city_type                     0
# previous_year_cost            0
# annual_medical_cost           0
# dtype: int64

# %%
medical_cost['insurance_type'].dtype

# as we know that insruance type is of object type so we cannot make use of mean mode median so first we have to convert it into numeric and then we have to
# Out:
# dtype('O')

# %%
medical_cost['insurance_type'].unique()
# Out:
# array(['Private', 'Government', nan], dtype=object)

# %% [markdown]
# So the conclusion is we cannot apply mean, median on object column
# We can only apply mode, ffill and bfill on the object column to fill it
#
# because mean fill the values by an average whreas median keep replace the value which is coming at middle
#
# Mode mean the value which is getting repetaed frequently
#
# Forward fill means -> Missing values will get replaced by previous values
#
# Backward fill means -> Missing values will get replaced by next values
#
#
# df['Department'].fillna(method='ffill', inplace=True)

# %%
# Filling values using mode
mode_value = medical_cost['insurance_type'].mode() [0]

# here we got the value of mode

# [0] -> modes return the series of repetated values but this 0 will choose the first values so that's why we use 0

# %%
medical_cost['insurance_type'].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-4197241878.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   medical_cost['insurance_type'].fillna(mode_value, inplace=True)

# %%
medical_cost['insurance_type'] = medical_cost['insurance_type'].fillna(mode_value)

# %%
medical_cost['insurance_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
# same we can use mean , median also

# %% [markdown]
# **Dropna**

# %%
medical_cost.dropna(inplace=True)
# inplace=True is used to make the changes directly to the original datsets

# %%
medical_cost.shape
# Out:
# (5000, 20)

# %%
medical_cost.shape
# Out:
# (5000, 20)

# %% [markdown]
# ## **2. Removing Duplicated data**

# %% [markdown]
# What to check?
#
# We have to check the dataset is having duplicate data or not
#
# what we have to do ?
#
# we have to remove the diplciated data

# %%
medical_cost.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
medical_cost['insurance_type'].duplicated()

# so here if we will see that this column insurance type is having duplicated data so we cannot delete this data we have to check the data first before performing any operation
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 4995     True
# 4996     True
# 4997     True
# 4998     True
# 4999     True
# Name: insurance_type, Length: 5000, dtype: bool

# %% [markdown]
# # **3. Incorrect Data-types**

# %% [markdown]
# Incorrect data types mean the age store in string and the data store in int type column so we have to fix that column data type. we have to convert it into int to data column type

# %%
# so for conversion we have to use this

# df['column_name'] = pd.to_datetime(df['column_name'], errors='coerce')

# %% [markdown]
# ## **4. Fix Inconsistent value**

# %% [markdown]
# Inconsistent value means let's suppose you're having an column Gender and its having a values Male, MALE, M , m , Female, FEMALE, F, f
#
# so we have to keep this data into standard format this is called inconsistent value so this value we have to fix it.

# %%
medical_cost
# Out:
#       age  gender   bmi smoker  diabetes  hypertension  heart_disease  asthma  \
# 0      69    Male  29.4     No         1             0              0       0
# 1      32  Female  22.9     No         1             0              0       0
# 2      89    Male  25.7     No         0             0              0       0
# 3      78    Male  31.9    Yes         0             1              0       0
# 4      38    Male  27.7     No         0             0              0       0
# ...   ...     ...   ...    ...       ...           ...            ...     ...
# 4995   77  Female  19.7    Yes         0             0              0       0
# 4996   43  Female  23.9    Yes         0             0              0       0
# 4997   58  Female  31.1     No         0             0              0       0
# 4998   53    Male  27.6     No         0             0              0       0
# 4999   40    Male  25.8     No         0             0              0       0
#
# ...

# %%
medical_cost['physical_activity_level'].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
medical_cost['physical_activity_level'] = medical_cost['physical_activity_level'].str.lower().str.strip().replace({'m':"male", 'f':"frmale"})

# %%
# here str.lower() this will convert all the value in lower format
# str.strip() this will remove all the gap which is there
# replace will replace all the values like m on male f on female

# %% [markdown]
# ## **5. Outlier**

# %% [markdown]
# Outlier it is a far away from the rest of the data
#
# lets suppose we're having an value
#
#
# 1000
#
# 2000
#
# 3000
#
# 4000
#
# 5000
#
# 1001010 -> Here the outlier has been detected so this we have to remove it
#
# Outlier means the data can be too high, too low or rare events

# %% [markdown]
# ## **Why outlier matters**

# %% [markdown]
# It will matter to ML models
#
# Sometime the outlier should be legit so we have to handle it properly by care

# %% [markdown]
# ## **Ways to detect the outlier**
#
# Type 01:
#
# ## **1. Summary Analysis - describe()**
#
# ### Look at the mix, max, mean, std
# ### If max is way higher than mean possible outlier

# %%
medical_cost.describe()
# Out:
#                age          bmi     diabetes  hypertension  heart_disease  \
# count  5000.000000  5000.000000  5000.000000   5000.000000     5000.00000
# mean     53.299000    25.970820     0.207600      0.288000        0.14220
# std      20.646851     5.046651     0.405629      0.452876        0.34929
# min      18.000000     6.400000     0.000000      0.000000        0.00000
# 25%      36.000000    22.600000     0.000000      0.000000        0.00000
# 50%      53.000000    25.900000     0.000000      0.000000        0.00000
# 75%      71.000000    29.400000     0.000000      1.000000        0.00000
# max      89.000000    43.600000     1.000000      1.000000        1.00000
#
#             asthma   daily_steps  sleep_hours  stress_level  \
# count  5000.000000   5000.000000  5000.000000   5000.000000
# mean      0.096400   7993.216800     6.488140      5.475400
# std       0.295169   4052.127069     1.443361      2.892312
# ...

# %% [markdown]
# ### **Type 02 : using boxplot**

# %%
import matplotlib.pyplot as plt

plt.boxplot(medical_cost['age'])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(medical_cost['age'])
plt.title("Line Plot of Age")
plt.show()

# %%
# if we are getting an outlier than we can remove it but before removing we have to check if its legit or not

# %%
# Okay so here we had done with the pandas clearning part now we will directly jump on visualization part then
# we will start with feature enginnering part.

# %% [markdown]
# # **Visualization Part**

# %% [markdown]
# So now we will visualize the data.

# %% [markdown]
# ### **1. Line Plot**

# %% [markdown]
# Line plot shows trends over time - when there's a sudden change or change.
#
# So for checking the change over something we make use of line plot
#
# Time -> X axis
#
# Value -> Y axis

# %%
import matplotlib.pyplot as plt

# %%
# plt.plot() : this takes two paramter one what we have to print on x axis and next what we have to print on Y axis

# %%
plt.plot(medical_cost['age'][:30], medical_cost['annual_medical_cost'][:30], marker='o')

# %% [markdown]
# ### **2. Bar graph**

# %% [markdown]
# Each bar represent a category
#
# The height of bar shows the value or count

# %%
plt.bar(medical_cost['age'], medical_cost['bmi'])
# Out:
# <BarContainer object of 5000 artists>

# %% [markdown]
# ## **3. Histogram**

# %% [markdown]
# Histogram is a type of bar chart that is used to show how often the values are occured in numeric column
#
# it groups number into ranges(bins) and show how many values fall in each ranges

# %%
plt.hist(medical_cost['daily_steps'], bins=10, color='skyblue', edgecolor='black')
# Out:
# (array([515., 468., 531., 506., 485., 499., 505., 474., 527., 490.]),
#  array([ 1004. ,  2403.5,  3803. ,  5202.5,  6602. ,  8001.5,  9401. ,
#         10800.5, 12200. , 13599.5, 14999. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## **4. Scattered Plot**

# %% [markdown]
# We use scattered plot when we want to show the relationship between two numeric values

# %%
import matplotlib.pyplot as plt

# Plot only first 30 patients
plt.scatter(medical_cost['age'][:30], medical_cost['annual_medical_cost'][:30], color='red')
plt.title("Annual Medical Cost vs Age (First 30 Patients)")
plt.xlabel("Age")
plt.ylabel("Annual Medical Cost")
plt.show()

# %% [markdown]
# 5. Pie Chart

# %%
import matplotlib.pyplot as plt

# Count of patients with and without diabetes
counts = medical_cost['diabetes'].value_counts()

# Create pie chart
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=['skyblue','orange'])
plt.title("Proportion of Patients with/without Diabetes")
plt.show()
