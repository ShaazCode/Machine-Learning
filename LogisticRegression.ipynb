# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaazCode/Machine-Learning/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !git config --global user.name "ShaazCode"

# %%
# !git config --global user.email "shaaz.code@gmail.com"

# %%
# !git clone https://github.com/ShaazCode/Machine-Learning.git
# Out:
# Cloning into 'Machine-Learning'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 60 (delta 23), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 479.39 KiB | 11.15 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %% [markdown]
# Logistic Regression is used for classification, it predict the catagorical value.
#
# 1. Binary classification. -> Only two possible output class
#
# 2. Multiclass classification. -> more than two output class
#
# 3. Multi-label classification. -> one feature belongs to multiple output class.

# %% [markdown]
# Sigmoid function basically used to convert the values input to range 0 to 1
#
# e = euler's number = 2.71828

# %% [markdown]
# # **When to use logistic Regression?**
#
# When the data is approximate linearly seperable. The data is not perfectly seperated it can be used still when the seperation cannot be perfect.
#
# so here if we see below in pic some blue dots are there in green portion whreas some gree dots are there in blue section dots.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here if you will see so the data is approximately linearly seperated by each other.
# Logistic Regression is just like a linear regression.
#
# If we apply logistic regression on non-linear data then we will not get the good result
#
# Logistic regression check the probability, like it belongs to which class.
#
# how it fix?
#
# It uses special function called sigmoid function that converts any number into a probability 0 and 1
#
# Shape S curve
#
# very low input -> Probability near zero
#
# Very high input -> Probability near one
#
# Predicition
# If Predicted probabiltiy > 0.5 then belongs to class 1
#
# If prediction probability < 0.5 then it belongs to class 0
#
#
# If we draw straight line for seperating the two classes logistic regression works well whreas if the data is curve then it will struggle so we can move towards svm and other

# %% [markdown]
# # **Sigmoid**

# %% [markdown]
# The sigmoid function is mathematical function that takes any real number as a input and convert it into a value between 0 to 1 (Probability).
#
# ![image.png](data:image/png;base64,...)
#
#
#
# his is logistic regression

# %%
I
